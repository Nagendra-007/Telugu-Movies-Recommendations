# %%
import pandas as pd
df1 = pd.read_csv('movies2011.csv')
df2 = pd.read_csv('movies2012.csv')
df3 = pd.read_csv('movies2013.csv')
df4 = pd.read_csv('movies2014.csv')
df5 = pd.read_csv('movies2015.csv')
df6 = pd.read_csv('movies2016.csv')
df7 = pd.read_csv('movies2017.csv')
df8 = pd.read_csv('movies2018.csv')
df9 = pd.read_csv('movies2019.csv')
df10 = pd.read_csv('movies2020_updated.csv')
df11 = pd.read_csv('movies2021_updated.csv')

# %%
df_1 =df1.append(df2.append(df3.append(df4.append(df5.append(df6,ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df =df_1.append(df7.append(df8.append(df9.append(df10.append(df11,ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.tail(125)
# Out:
#                          Title            Director  \
# 1064                     wifei         gssp kalyan
# 1065       sarileru neekevvaru       anil ravipudi
# 1066    ala vaikunthapurramloo  trivikram srinivas
# 1067    entha manchivaadavuraa      satish vegesna
# 1068          thagite thandana    srinath badineni
# ...                        ...                 ...
# 1184                    pushpa             sukumar
# 1185             maha samudram       ajay bhupathi
# 1186  f3 : fun and frustration       anil ravipudi
# 1187                     liger      puri jagannadh
# 1188                       rrr     s. s. rajamouli
#
#                                                    Cast                genres  \
# 1064                 Abhishek Reddy Sakshi Sidiya Kavya                Comedy
# 1065  Mahesh Babu Rashmika Mandanna Vijayashanti Pra...                Action
# 1066  Allu Arjun Pooja Hegde Tabu Jayaram Sushanth N...          Action Drama
# ...

# %%
dict = {
       'Title' : ['k.g.f: chapter 1','k.g.f: chapter 2','singam II', 'si 3'],
       'Director' : ['prashanth neel','prashanth neel','hari', 'hari'],
       'Cast' : ['yash srinidhi shetty achyuth kumar anant nag malavika avinash', 'yash srinidhi shetty achyuth kumar anant nag malavika avinash','suriya anushka shetty hansika motwani vivek santhanam danny sapani', 'suriya anushka shetty shruti haasan radha ravi nassar thakur anoop singh'],
       'genres' : ['action drama', 'action drama','action comedy crime','action crime' ],
       'combo' : ['k.g.f: chapter 1 prashanth neel yash srinidhi shetty achyuth kumar anant nag malavika avinash action drama','k.g.f: chapter 1 prashanth neel yash srinidhi shetty achyuth kumar anant nag malavika avinash action drama', 'singam II hari suriya anushka shetty hansika motwani vivek santhanam danny sapani action comedy crime','si 3 hari suriya anushka shetty shruti haasan radha ravi nassar thakur anoop singh action crime']
      }
df2 = pd.DataFrame(dict)

# %% [markdown]
# #x = df.iloc[[1191],[]
# df.at[1191,'Title'] = 'f3: fun and frustration'

# %%
df = df.append(df2, ignore_index = True)

# %%
df = df.reset_index()

# %%
df.tail(30)
# Out:
#       index                      Title              Director  \
# 1163   1163    thellavarithe guruvaram       manikanth gelli
# 1164   1164                yuvarathnaa    santhosh ananddram
# 1165   1165                 seetimaarr         sampath nandi
# 1166   1166                   wild dog      ashishor solomon
# 1167   1167                vakeel saab           venu sriram
# 1168   1168                 love story        sekhar kammula
# 1169   1169              tuck jagadish         shiva nirvana
# 1170   1170                   thalaivi           a. l. vijay
# 1171   1171              virata parvam          venu udugula
# 1172   1172                     paagal  naresh reddy kuppili
# 1173   1173                    acharya         koratala siva
# 1174   1174                   naarappa       srikanth addala
# 1175   1175                    khiladi          ramesh varma
# 1176   1176                        bb3        boyapati srinu
# ...

# %%
df.to_csv('final_data.csv',  index = False)

# %%
#df2 = pd.read_csv('movies2019.csv')

# %%
#df2
