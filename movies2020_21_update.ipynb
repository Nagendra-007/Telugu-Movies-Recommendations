# %%
import pandas as pd
import numpy as np
df = pd.read_csv('movies2020_updated.csv')
# for year 2020 data set we have to delete 40th row
#df = df.drop([40],axis = 0)
df
# Out:
#                       Title        Director  \
# 0                 beautiful  agasthya manju
# 1         oollalla oollalla   satya prakash
# 2                   utthara   sr thirupathi
# 3                     wifei     gssp kalyan
# 4       sarileru neekevvaru   anil ravipudi
# ..                      ...             ...
# 57            guvva gorinka   bammidi mohan
# 58               dirty hari      m. s. raju
# 59                   murder   anand chandra
# 60  solo brathuke so better           subbu
# 61              oka yodhudu           haari
#
#                                                  Cast            genres  \
# 0                            Parth Suri Naina Ganguly             Drama
# 1          Nataraj Noorin Shereef Ankeeta R Maharanaa          un_known
# 2                 Sreeram Karronya Katrynn Ajay Ghosh          un_known
# 3                  Abhishek Reddy Sakshi Sidiya Kavya            Comedy
# ...

# %%
df = df.reset_index(drop=True)

# %%
df1 = pd.read_csv('cast2021.csv')
df1
# Out:
#                                                  cast
# 0   Ravi Teja Shruti Haasan Varalaxmi Sarathkumar ...
# 1   Priyadarshi Pulikonda Harshith Malgireddy Mani...
# 2   Ram Pothineni Nivetha Pethuraj Malvika Sharma ...
# 3   Bellamkonda Sreenivas Nabha Natesh Anu Emmanue...
# 4   Punarnavi Bhupalam Mahat Raghavendra Sudarshan...
# ..                                                ...
# 61  Allu Arjun Rashmika Mandanna Jagapathi Babu Pr...
# 62  Sharwanand Siddharth Aditi Rao Hydari Anu Emma...
# 63      Venkatesh Varun Tej Tamannaah Mehreen Pirzada
# 64  Vijay Deverakonda Ananya Panday Ramya Krishna ...
# 65  N. T. Rama Rao Jr Ram Charan Ajay Devgn Alia B...
#
# [66 rows x 1 columns]

# %%
df['Cast'] = df1['cast']

# %% [markdown]
# df = df.drop(['genres','combo'], axis =1)

# %%
df['combo'] = df['Title']+' '+df['Director']+' '+df['Cast']+' '+df['genres']

# %%
df
# Out:
#                        Title            Director  \
# 0                      krack  gopichand malineni
# 1                       mail        uday gurrala
# 2                        red    kishore tirumala
# 3              alludu adhurs   santhosh srinivas
# 4                      cycle   aatla arjun reddy
# ..                       ...                 ...
# 61                    pushpa             sukumar
# 62             maha samudram       ajay bhupathi
# 63  f3 : fun and frustration       anil ravipudi
# 64                     liger      puri jagannadh
# 65                       rrr     s. s. rajamouli
#
#                                                  Cast          genres  \
# 0   Ravi Teja Shruti Haasan Varalaxmi Sarathkumar ...        un_known
# 1   Priyadarshi Pulikonda Harshith Malgireddy Mani...  Comedy Romance
# 2   Ram Pothineni Nivetha Pethuraj Malvika Sharma ...  Drama Thriller
# 3   Bellamkonda Sreenivas Nabha Natesh Anu Emmanue...  Romance Comedy
# ...

# %%
df.to_csv('movies2021_updated.csv', index = False)

# %%
dt = pd.read_csv('movies2021_updated.csv')
dt
# Out:
#                        Title            Director  \
# 0                      krack  gopichand malineni
# 1                       mail        uday gurrala
# 2                        red    kishore tirumala
# 3              alludu adhurs   santhosh srinivas
# 4                      cycle   aatla arjun reddy
# ..                       ...                 ...
# 61                    pushpa             sukumar
# 62             maha samudram       ajay bhupathi
# 63  f3 : fun and frustration       anil ravipudi
# 64                     liger      puri jagannadh
# 65                       rrr     s. s. rajamouli
#
#                                                  Cast          genres  \
# 0   Ravi Teja Shruti Haasan Varalaxmi Sarathkumar ...        un_known
# 1   Priyadarshi Pulikonda Harshith Malgireddy Mani...  Comedy Romance
# 2   Ram Pothineni Nivetha Pethuraj Malvika Sharma ...  Drama Thriller
# 3   Bellamkonda Sreenivas Nabha Natesh Anu Emmanue...  Romance Comedy
# ...
